# %% [raw]
# ---
# description: This is the completed state of the example of microbeseq_nbdev_augment.
#   It deploys the nbdev changes and implements a core notebook and a hello_world notebook.
#   Each of these have a command line function which are described in `How to use`.
#   In making your own package, it is recommended to remove `01_hello_world.ipynb`.
# output-file: index.html
# title: microbeseq_nbdev_example
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install microbeseq_nbdev_example
# ```

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
! core_hello_world -h
# Out:
# usage: core_hello_world [-h] [--config_file CONFIG_FILE] name
#
# This will print Hello World! with your name
#
# positional arguments:
#   name                       Your name
#
# options:
#   -h, --help                 show this help message and exit
#   --config_file CONFIG_FILE  config file to set env vars from

# %%
! hello_two_world -h
# Out:
# usage: hello_two_world [-h] [--name NAME] [--alternative_name ALTERNATIVE_NAME]
#                        [--config_file CONFIG_FILE]
#
# This will print Hello World! with your name
#
# options:
#   -h, --help                           show this help message and exit
#   --name NAME                          A name
#   --alternative_name ALTERNATIVE_NAME  An alternative name
#   --config_file CONFIG_FILE            config file to set env vars from
